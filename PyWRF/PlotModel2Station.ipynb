# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "rh2"
Title = "Time Series of Two Meter Relative Humidity [%]"
YLabel = "Two Meter Relative Humidity [%]"
lat_point = 38.593333
lon_point = -121.503806
## Load the EPA Data Input File
DataVal = np.loadtxt("/data/wto/EPAMetData/hourly_RH_DP_2020_06_Dixon.csv", delimiter=',',max_rows=718,usecols=[13])
# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP8_RAD4_250711/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP2_RAD4_250805/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP6_RAD4_250730/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP38_RAD4_250804/wrfout_d01_2020-06-*"]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYNN2.5/Thompson/RRTMG","MYNN2.5/PurdueLin/RRTMG","MYNN2.5/WSM6/RRTMG","MYNN2.5/Thompson2M/RRTMG"],Show=True)
print(results)
# Out:
# [[-20.42132607409549, -20.11089232107391, -20.067891011331074, -20.321953834597448], [22.394344096645174, 22.173494749097127, 22.082943296593434, 22.34301339396694], [0.7558428640190762, 0.7566103883140453, 0.7576605112635842, 0.7532072430421092]]

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "rh2"
Title = "Time Series of Two Meter Relative Humidity [%]"
YLabel = "Two Meter Relative Humidity [%]"
lat_point = 38.302591
lon_point = -121.420838
## Load the EPA Data Input File
DataVal = np.loadtxt("/data/wto/EPAMetData/hourly_RH_DP_2020_06_Franklin.csv", delimiter=',',max_rows=718,usecols=[13])
# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP8_RAD4_250711/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP2_RAD4_250805/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP6_RAD4_250730/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP38_RAD4_250804/wrfout_d01_2020-06-*"]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYNN2.5/Thompson/RRTMG","MYNN2.5/PurdueLin/RRTMG","MYNN2.5/WSM6/RRTMG","MYNN2.5/Thompson2M/RRTMG"],Show=True)
print(results)
# Out:
# [[-7.577598336679357, -7.349163938033548, -7.3008000956936465, -7.527519468477509], [11.298529128408283, 11.251767640152458, 11.217827708804608, 11.372858786491477], [0.9291734223416492, 0.9276415836707488, 0.9278462500067985, 0.9259419890792742]]

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "rh2"
Title = "Time Series of Two Meter Relative Humidity [%]"
YLabel = "Two Meter Relative Humidity [%]"
lat_point = 37.950741
lon_point = -121.268523
## Load the EPA Data Input File
DataVal = np.loadtxt("/data/wto/EPAMetData/hourly_RH_DP_2020_06_Stockton.csv", delimiter=',',max_rows=718,usecols=[13])
# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP8_RAD4_250711/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP2_RAD4_250805/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP6_RAD4_251118/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP38_RAD4_250804/wrfout_d01_2020-06-*"]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYNN2.5/Thompson/RRTMG","MYNN2.5/PurdueLin/RRTMG","MYNN2.5/WSM6/RRTMG","MYNN2.5/Thompson2M/RRTMG"],Show=True)
print(results)
# Out:
# [[-6.623134329458465, -5.8511307232891285, -5.815472557684174, -5.997758579121328], [11.17596117933023, 10.827899465231576, 10.733401797995903, 10.856554788970714], [0.8894590298364106, 0.8965435122072254, 0.8980967480439083, 0.8956993508916452]]

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "T2"
Title = "Time Series of Two-Meter Temperature [°C]"
YLabel = "Two-Meter Temperature [°C]"
lat_point = 37.950741
lon_point = -121.268523
## Load the EPA Data Input File
#DataVal = (np.loadtxt("/data/wto/EPAMetData/hourly_TEMP_2020_06_Stockton_test.csv", delimiter=',',max_rows=718,usecols=[13])-32)*5/9

import pandas as pd
DataDF = pd.read_csv("/data/wto/EPAMetData/hourly_TEMP_2020_06_Stockton_test.csv", header=None,usecols=[11,12,13], names=["date","time","value"])
DataDF["datetime"] = pd.to_datetime(DataDF["date"] + " " + DataDF["time"])
DataDF = DataDF.set_index("datetime").sort_index()
print(DataDF)
import matplotlib.pyplot as plt

plt.figure(figsize=(14,5))

plt.plot(DataDF.index, DataDF["value"], 'k.', markersize=6)

plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Hourly Values vs Time (June 2020)")
plt.grid(True)

plt.show()
# Out:
#                            date   time  value
# datetime
# 2020-06-01 00:00:00  2020-06-01  00:00   76.6
# 2020-06-01 01:00:00  2020-06-01  01:00   75.7
# 2020-06-01 02:00:00  2020-06-01  02:00   74.1
# 2020-06-01 03:00:00  2020-06-01  03:00   71.2
# 2020-06-01 04:00:00  2020-06-01  04:00   68.7
# ...                         ...    ...    ...
# 2020-06-30 06:00:00  2020-06-30  06:00   72.1
# 2020-06-30 20:00:00  2020-06-30  20:00   89.8
# 2020-06-30 21:00:00  2020-06-30  21:00   91.6
# 2020-06-30 22:00:00  2020-06-30  22:00   92.8
# 2020-06-30 23:00:00  2020-06-30  23:00   94.1
#
# [664 rows x 3 columns]

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "T2"
Title = "Time Series of Two-Meter Temperature [°C]"
YLabel = "Two-Meter Temperature [°C]"
lat_point = 37.950741
lon_point = -121.268523
## Load the EPA Data Input File
DataVal = (np.loadtxt("/data/wto/EPAMetData/hourly_TEMP_2020_06_Stockton.csv", delimiter=',',max_rows=718,usecols=[13])-32)*5/9

# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL1_FDDA1_MP6_RAD1_251126/wrfout_d01_2020-06-*",
           "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL1_FDDA1_MP6_RAD3_251127/wrfout_d01_2020-06-*",
           "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL1_FDDA1_MP6_RAD4_250718/wrfout_d01_2020-06-*",
           "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL1_FDDA1_MP6_RAD5_251128/wrfout_d01_2020-06-*",]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point, offset=-273.15)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYNN2.5/Thompson/RRTMG","MYNN2.5/PurdueLin/RRTMG","MYNN2.5/WSM6/RRTMG","MYNN2.5/Thompson2M/RRTMG"],Show=True)
print(results)
# Out:
# [[-0.5568309815813013, -0.8530598844990197, -0.09633432882407636, -0.05035921484644753], [2.434550974512357, 2.723061577242588, 2.3946992334374464, 2.411751316549166], [0.9615355459880998, 0.9544705638619002, 0.9630532614959237, 0.9628098978640796]]

# %% [markdown]
# here

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "T2"
Title = "Time Series of Two-Meter Temperature [°C]"
YLabel = "Two-Meter Temperature [°C]"
lat_point = 38.593322
lon_point = -121.503795
## Load the EPA Data Input File
DataVal = (np.loadtxt("/data/wto/EPAMetData/hourly_TEMP_2020_06_Sac.csv", delimiter=',',max_rows=718,usecols=[13])-32)*5/9
#print(len(DataVal))

# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP8_RAD4_250711/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP2_RAD4_250805/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP6_RAD4_250730/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL5_FDDA1_MP38_RAD4_250804/wrfout_d01_2020-06-*"]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point, offset=-273.15)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYNN2.5/Thompson/RRTMG","MYNN2.5/PurdueLin/RRTMG","MYNN2.5/WSM6/RRTMG","MYNN2.5/Thompson2M/RRTMG"],Show=True)
print(results)
# Out:
# [[1.2203007416177858, 0.8298601221942569, 0.7994832734580758, 0.8567542692117969], [2.2657196541552294, 1.83311691079216, 1.8243753765652837, 1.8818573620043908], [0.973216197043207, 0.9813806465827737, 0.9815107649041002, 0.9804807869993503]]

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "T2"
Title = "Time Series of Two-Meter Temperature [°C]"
YLabel = "Two-Meter Temperature [°C]"
lat_point = 38.302591
lon_point = -121.420838
## Load the EPA Data Input File
DataVal = (np.loadtxt("/data/wto/EPAMetData/hourly_TEMP_2020_06_Franklin.csv", delimiter=',',max_rows=718,usecols=[13])-32)*5/9
#print(len(DataVal))

# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD4_250710/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL1_FDDA1_MP8_RAD4_250714/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD3_251201/wrfout_d01_2020-06-*"]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point, offset=-273.15)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYJ/Thomson/RRTMG","YSU/Thomson/RRTMG","YSU/Thomson/CAM"],Show=True)
print(results)

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "T2"
Title = "Time Series of Two-Meter Temperature [°C]"
YLabel = "Two-Meter Temperature [°C]"
lat_point = 38.302591
lon_point = -121.420838
## Load the EPA Data Input File
DataVal = (np.loadtxt("/data/wto/EPAMetData/hourly_TEMP_2020_06_Franklin.csv", delimiter=',',max_rows=718,usecols=[13])-32)*5/9
#print(len(DataVal))

# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD4_250710/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL1_FDDA1_MP8_RAD4_250714/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD3_251201/wrfout_d01_2020-06-*"]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point, offset=-273.15)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYJ/Thomson/RRTMG","YSU/Thomson/RRTMG","YSU/Thomson/CAM"],Show=True)
print(results)

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "rh2"
Title = "Time Series of Two Meter Relative Humidity [%]"
YLabel = "Two Meter Relative Humidity [%]"
lat_point = 38.4347
lon_point = -121.8565
## Load the EPA Data Input File
DataVal = np.loadtxt("/data/wto/EPAMetData/hourly_RH_DP_2020_06_Dixon.csv", delimiter=',',max_rows=718,usecols=[13])
# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD4_250710/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL1_FDDA1_MP8_RAD4_250714/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD3_251201/wrfout_d01_2020-06-*"]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYJ/Thomson/RRTMG","YSU/Thomson/RRTMG","YSU/Thomson/CAM"],Show=True)
print(results)

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "rh2"
Title = "Time Series of Two Meter Relative Humidity [%]"
YLabel = "Two Meter Relative Humidity [%]"
lat_point = 38.302591
lon_point = -121.420838
## Load the EPA Data Input File
DataVal = np.loadtxt("/data/wto/EPAMetData/hourly_RH_DP_2020_06_Franklin.csv", delimiter=',',max_rows=718,usecols=[13])
# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD4_250710/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL1_FDDA1_MP8_RAD4_250714/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD3_251201/wrfout_d01_2020-06-*"]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYJ/Thomson/RRTMG","YSU/Thomson/RRTMG","YSU/Thomson/CAM"],Show=True)
print(results)

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "wspd10"
Title = "Time Series of 10-m Wind Speed [m/s]"
YLabel = "10-m Wind Speed [m/s]"
lat_point = 38.593322
lon_point = -121.503795
## Load the EPA Data Input File
DataVal = np.loadtxt("/data/wto/EPAMetData/hourly_WINDMAG_2020_06_Dixon.csv", delimiter=',',max_rows=718,usecols=[13])*0.514444
# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD4_250710/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL1_FDDA1_MP8_RAD4_250714/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD3_251201/wrfout_d01_2020-06-*"]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYJ/Thomson/RRTMG","YSU/Thomson/RRTMG","YSU/Thomson/CAM"],Show=True)
print(results)

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "wspd10"
Title = "Time Series of 10-m Wind Speed [m/s]"
YLabel = "10-m Wind Speed [m/s]"
lat_point = 38.302591
lon_point = -121.420838
## Load the EPA Data Input File
DataVal = np.loadtxt("/data/wto/EPAMetData/hourly_WINDMAG_2020_06_Franklin.csv", delimiter=',',max_rows=718,usecols=[13])*0.514444
# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD4_250710/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL1_FDDA1_MP8_RAD4_250714/wrfout_d01_2020-06-*",
            "/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD3_251201/wrfout_d01_2020-06-*"]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYJ/Thomson/RRTMG","YSU/Thomson/RRTMG","YSU/Thomson/CAM"],Show=True)
print(results)

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries, MonthGlob

# === Inputs ===
Var = "wdir10"
Title = "Time Series of 10-m Wind Direction [$^\circ$]"
YLabel = "10-m Wind Direction [$^\circ$]"
lat_point = 39.18919
lon_point = -121.99887
## Load the EPA Data Input File
DataVal = np.loadtxt("/data/wto/EPAMetData/hourly_WINDDIR_2020_06_Dixon.csv", delimiter=',',max_rows=718,usecols=[13])
# === Get monthly WRF Values ===
WRFFiles = ["/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_MP8_RAD4_250710/wrfout_d01_2020-06-*"]
Time, Vals = MonthGlob(WRFFiles, Var, lat_point, lon_point)
# Concatenate the Data and WRF Values The [] around DataVal is needed to make sure it adds the array into the list.
Vals = [DataVal] + Vals
# === Call MonthTimeSeries plot function ===
results = MonthTimeSeries(Time,Vals,Title,YLabel, ["EPA Data","MYJ"],Show=True)
print(results)
